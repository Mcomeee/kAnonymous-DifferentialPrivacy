# %% [markdown]
#    # KACA算法
#    ## 步骤：
#    KACA(D,k):
#    begin
#    1. 由数据集D中生成初始等价类，等价类中各个元组在准标识符上值相等。
#    2. 循环，知道不存在元组个数小于k的等价类
#        1. 随机选择一个大小小于k的等价类C
#        2. 计算C与其他所有等价类的距离
#        3. 找到距C最近的等价类C'
#        4. 将C和C'并为一类，并泛化C和C'
#        循环结束
#    3. 返回匿名表
#    end;

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

# %%
AGECONFFILE = 'conf/age_hierarchy.txt'
WORKCONFFILE = 'conf/workclass_hierarchy.txt'
EDUCONFFILE = 'conf/edu_hierarchy.txt'
EDUNUMCONFFILE = 'conf/edunum_hierarchy.txt'
MARITALCONFFILE = 'conf/marital_hierarchy.txt'
OCCUCONFFILE = 'conf/occupation_hierarchy.txt'
RELATECONFFILE = 'conf/relate_hierarchy.txt'
RACECONFFILE = 'conf/race_hierarchy.txt'
SEXCONFFILE = 'conf/sex_hierarchy.txt'
COUNTRYCONFFILE = 'conf/country_hierarchy.txt'
ATTNAME = ['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status',
           'occupation', 'relationship', 'race', 'sex', 
            'capital_gain', 'capital_loss', 'hours_per_week', 'native_country', 'incom']
towrite_sort = None

# %%
def readdata():
    df=pd.read_csv('adult.data.txt',names = ['age', 'workclass', 'fnlwgt','education','education_num','marital_status','occupation','relationship','race','sex','capital_gain','capital_loss','hours_per_week','native_country','incom'],header=None)
    return df

# %%
class KAnonymity():
    def   __init__(self, records):
        self.records = records
        #self.confile = [AGECONFFILE, EDUCONFFILE, MARITALCONFFILE, RACECONFFILE]
        #self.confile = [AGECONFFILE, EDUCONFFILE, EDUNUMCONFFILE, MARITALCONFFILE,RACECONFFILE]
        self.confile = [AGECONFFILE, EDUCONFFILE]
    
    def anonymize(self, qi_names=['age', 'education', 'marital_status', 'race'], k=5):
        domains, gen_levels = {},{}
        qi_frequency ={}
        assert len(self.confile) == len(qi_names), 'number of config files  not equal to number of QI-names'
        generalize_tree = dict()
        
        for idx, name  in enumerate(qi_names):
            generalize_tree[name]=Tree(self.confile[idx])
            
        for qiname in qi_names:
            domains[qiname]=set()
            gen_levels[qiname]=0
        
        for idx,record in self.records.iterrows():
            qi_sequence = self._get_qi_values(record[:], qi_names, generalize_tree)
            #qi_sequence=tuple(record)
            #print(qi_sequence)
            if qi_sequence in qi_frequency:
                qi_frequency[qi_sequence].add(idx)
            else:
                qi_frequency[qi_sequence] = {idx}
                for j, value in enumerate(qi_sequence):
                    domains[qi_names[j]].add(value)
        
        # 迭代泛化
        while True:
            # 计算不满足k-匿名的记录数
            negcount = 0
            for qi_sequence, idxset in qi_frequency.items():
                if len(idxset) < k:
                    negcount += len(idxset)
            
            if negcount > k:
                # 如果>k，不满足k-匿名，继续泛化
                most_freq_att_num, most_freq_att_name = -1, None
                for qiname in qi_names:
                    if len(domains[qiname]) > most_freq_att_num:
                        most_freq_att_num = len(domains[qiname])
                        most_freq_att_name = qiname
                
                # 找出有最多不同值的属性
                generalize_att = most_freq_att_name
                qi_index = qi_names.index(generalize_att)
                domains[generalize_att] = set()
                
                # 往上泛化
                for qi_sequence in list(qi_frequency.keys()):
                    new_qi_sequence = list(qi_sequence)
                    new_qi_sequence[qi_index] =  generalize_tree[generalize_att].root[qi_sequence[qi_index]][0]
                    new_qi_sequence = tuple(new_qi_sequence)
                    
                    if new_qi_sequence == qi_sequence:
                        continue
                    if new_qi_sequence in qi_frequency:
                        qi_frequency[new_qi_sequence].update(
                            qi_frequency[qi_sequence])
                        qi_frequency.pop(qi_sequence, 0)
                    else:
                        qi_frequency[new_qi_sequence] = qi_frequency.pop(qi_sequence)
                    
                    #print(qi_frequency[new_qi_sequence])
                    
                    #if {0}.issubset(qi_frequency[new_qi_sequence]):
                        #print(new_qi_sequence)
                    domains[generalize_att].add(new_qi_sequence[qi_index])
                
                gen_levels[generalize_att] += 1
                
            
            else:
                genlvl_att = [0 for _ in range(len(qi_names))]
                dgh_att = [generalize_tree[name].level for name in qi_names]
                datasize = 0
                qiindex = [ATTNAME.index(name) for name in qi_names]

                # 确保输出文件与原始数据文件保持相同的顺序
                towriterecords = [[None,None,None,None,None,None,None,None,None,None,None,None,None,None,None]  
                                   for _ in range(len(self.records))]
                towriterecords = pd.DataFrame(towriterecords)
                global towrite_sort
                #towriterecords = None
                for qi_sequence, recordidxs in qi_frequency.items():
                    if len(recordidxs) < k:
                        continue
                    for idx in recordidxs:
                        record = self.records.loc[idx][:]
                        for i in range(len(qiindex)):
                            record[qiindex[i]] = qi_sequence[i]
                            genlvl_att[i] += generalize_tree[qi_names[i]].root[qi_sequence[i]][1]
                        record = list(map(str, record))
                        for i in range(len(record)):
                             if record[i] == '*' and i not in qiindex:
                                record[i] = '?'
                        tmp = pd.DataFrame(record).T
                        towriterecords.iloc[idx]=tmp.iloc[0]
                        if towrite_sort is None:
                            towrite_sort = tmp
                        else:
                            towrite_sort = towrite_sort.append(tmp,ignore_index=True)
                    datasize += len(recordidxs)
                    
                towriterecords.columns=['age', 'workclass', 'fnlwgt','education','education_num','marital_status','occupation','relationship','race','sex','capital_gain','capital_loss','hours_per_week','native_country','incom']
                towrite_sort.columns=['age', 'workclass', 'fnlwgt','education','education_num','marital_status','occupation','relationship','race','sex','capital_gain','capital_loss','hours_per_week','native_country','incom']
                towriterecords.to_csv('data/adult_%d_kanonymity.data' %k,index=False)
                print('qi names: ', qi_names)
                precision = self.calc_precision(genlvl_att, dgh_att, len(self.records), len(qi_names))
                distoration = self.calc_distoration([gen_levels[qi_names[i]] for i in range(len(qi_names))], dgh_att, len(qi_names))
                print('precision: {}, distoration: {}'.format(precision, distoration))
                break 
        return towriterecords
    
    def calc_precision(self, genlvl_att, dgh_att, datasize, attsize = 4):
        return 1 - sum([genlvl_att[i] / dgh_att[i] for i in range(attsize)])/(datasize*attsize)

    def calc_distoration(self, gen_levels_att, dgh_att, attsize):
        print('attribute gen level:', gen_levels_att)
        print('tree height:', dgh_att)
        return sum([gen_levels_att[i] / dgh_att[i] for i in range(attsize)]) / attsize

        
    def _get_qi_values(self, record, qi_names, generalize_tree):
        qi_index = [ATTNAME.index(name) for name in qi_names]
        seq = []
        for idx in qi_index:
            if idx == ATTNAME.index('age'):
                if record[idx] == -1:
                    seq.append('0-100')
                else:
                    seq.append(str(record[idx]))
            elif idx == ATTNAME.index('education_num'):
                seq.append(str(record[idx]))
            else:
                if record[idx] == '*':
                    record[idx] = generalize_tree[qi_names[idx]].highestgen
                seq.append(record[idx][1:])
        return tuple(seq)

# %%
class Tree:

    def __init__(self, confile):
        self.confile = confile
        self.root = dict()
        self.level = -1
        self.highestgen = ''
        self.buildTree()
        
    
    def buildTree(self):

        with open(self.confile, 'r') as rf:
            for line in rf:
                line = line.strip()
                if not line:
                    continue
                line = [col.strip() for col in line.split(',')]
                height = len(line)-1
                if self.level == -1:
                    self.level = height
                if not self.highestgen:
                    self.highestgen = line[-1]
                pre = None
                for idx, val in enumerate(line[::-1]):
                    self.root[val] = (pre, height-idx)
                    pre = val

# %%
df = readdata()
KAnony = KAnonymity(df)
newdf=KAnony.anonymize(qi_names=['age', 'education','education_num', 'marital_status', 'race'], k = 10)
newdf
# Out:
# qi names:  ['age', 'education', 'education_num', 'marital_status', 'race']
# attribute gen level: [2, 2, 2, 2, 1]
# tree height: [3, 4, 4, 3, 2]
# precision: 0.43350736566239767, distoration: 0.5666666666666667
#           age          workclass  fnlwgt         education education_num  \
# 0        0-50          State-gov   77516        ProfSchool         13-16
# 1      50-100   Self-emp-not-inc   83311        ProfSchool         13-16
# 2        0-50            Private  215646    AdvancedSchool          6-12
# 3      50-100            Private  234721    AdvancedSchool          6-12
# 4        0-50            Private  338409        ProfSchool         13-16
# 5        0-50            Private  284582        ProfSchool         13-16
# 6        0-50            Private  160187  CompulsorySchool           1-5
# 7      50-100   Self-emp-not-inc  209642    AdvancedSchool          6-12
# 8        0-50            Private   45781        ProfSchool         13-16
# 9        0-50            Private  159449        ProfSchool         13-16
# 10       0-50            Private  280464    AdvancedSchool          6-12
# 11       0-50          State-gov  141297        ProfSchool         13-16
# 12       0-50            Private  122272        ProfSchool         13-16
# 13       0-50            Private  205019        ProfSchool          6-12
# 14       0-50            Private  121772    AdvancedSchool          6-12
# 15       0-50            Private  245487  CompulsorySchool           1-5
# 16       0-50   Self-emp-not-inc  176756    AdvancedSchool          6-12
# 17       0-50            Private  186824    AdvancedSchool          6-12
# 18       0-50            Private   28887    AdvancedSchool          6-12
# 19       0-50   Self-emp-not-inc  292175        ProfSchool         13-16
# 20       0-50            Private  193524        ProfSchool         13-16
# 21     50-100            Private  302146    AdvancedSchool          6-12
# 22       0-50        Federal-gov   76845  CompulsorySchool           1-5
# 23       0-50            Private  117037    AdvancedSchool          6-12
# 24     50-100            Private  109015    AdvancedSchool          6-12
# 25     50-100          Local-gov  216851        ProfSchool         13-16
# 26       0-50            Private  168294    AdvancedSchool          6-12
# 27     50-100                  ?  180211    AdvancedSchool          6-12
# 28       0-50            Private  367260    AdvancedSchool          6-12
# 29       0-50            Private  193366    AdvancedSchool          6-12
# ...       ...                ...     ...               ...           ...
# 32531    0-50                  ?   33811        ProfSchool         13-16
# 32532    0-50            Private  204461        ProfSchool         13-16
# 32533  50-100            Private  337992        ProfSchool         13-16
# 32534    0-50            Private  179137    AdvancedSchool          6-12
# 32535    0-50            Private  325033    AdvancedSchool          6-12
# 32536    0-50            Private  160216        ProfSchool         13-16
# 32537    0-50            Private  345898    AdvancedSchool          6-12
# 32538    0-50            Private  139180        ProfSchool         13-16
# 32539  50-100                  ?  287372        ProfSchool         13-16
# 32540    0-50          State-gov  252208    AdvancedSchool          6-12
# 32541    0-50                  ?  202822    AdvancedSchool          6-12
# 32542  50-100                  ?  129912    AdvancedSchool          6-12
# 32543    0-50          Local-gov  119199        ProfSchool          6-12
# 32544    0-50            Private  199655        ProfSchool         13-16
# 32545    0-50          Local-gov  111499        ProfSchool          6-12
# 32546    0-50            Private  198216        ProfSchool          6-12
# 32547    0-50            Private  260761    AdvancedSchool          6-12
# 32548  50-100   Self-emp-not-inc   99359    AdvancedSchool         13-16
# 32549    0-50          State-gov  255835    AdvancedSchool          6-12
# 32550    0-50   Self-emp-not-inc   27242    AdvancedSchool          6-12
# 32551    0-50            Private   34066    AdvancedSchool          6-12
# 32552    0-50            Private   84661    AdvancedSchool          6-12
# 32553    0-50            Private  116138        ProfSchool         13-16
# 32554  50-100            Private  321865        ProfSchool         13-16
# 32555    0-50            Private  310152    AdvancedSchool          6-12
# 32556    0-50            Private  257302        ProfSchool          6-12
# 32557    0-50            Private  154374    AdvancedSchool          6-12
# 32558  50-100            Private  151910    AdvancedSchool          6-12
# 32559    0-50            Private  201490    AdvancedSchool          6-12
# 32560  50-100       Self-emp-inc  287927    AdvancedSchool          6-12
#
#       marital_status          occupation     relationship      race      sex  \
# 0         NonMarried        Adm-clerical    Not-in-family  Occident     Male
# 1            Married     Exec-managerial          Husband  Occident     Male
# 2            Married   Handlers-cleaners    Not-in-family  Occident     Male
# 3            Married   Handlers-cleaners          Husband    Orient     Male
# 4            Married      Prof-specialty             Wife    Orient   Female
# 5            Married     Exec-managerial             Wife  Occident   Female
# 6            Married       Other-service    Not-in-family    Orient   Female
# 7            Married     Exec-managerial          Husband  Occident     Male
# 8         NonMarried      Prof-specialty    Not-in-family  Occident   Female
# 9            Married     Exec-managerial          Husband  Occident     Male
# 10           Married     Exec-managerial          Husband    Orient     Male
# 11           Married      Prof-specialty          Husband    Orient     Male
# 12        NonMarried        Adm-clerical        Own-child  Occident   Female
# 13        NonMarried               Sales    Not-in-family    Orient     Male
# 14           Married        Craft-repair          Husband    Orient     Male
# 15           Married    Transport-moving          Husband  Occident     Male
# 16        NonMarried     Farming-fishing        Own-child  Occident     Male
# 17        NonMarried   Machine-op-inspct        Unmarried  Occident     Male
# 18           Married               Sales          Husband  Occident     Male
# 19           Married     Exec-managerial        Unmarried  Occident   Female
# 20           Married      Prof-specialty          Husband  Occident     Male
# 21           Married       Other-service        Unmarried    Orient   Female
# 22           Married     Farming-fishing          Husband    Orient     Male
# 23           Married    Transport-moving          Husband  Occident     Male
# 24           Married        Tech-support        Unmarried  Occident   Female
# 25           Married        Tech-support          Husband  Occident     Male
# 26        NonMarried        Craft-repair        Own-child  Occident     Male
# 27           Married                   ?          Husband    Orient     Male
# 28           Married     Exec-managerial    Not-in-family  Occident     Male
# 29           Married        Craft-repair          Husband  Occident     Male
# ...              ...                 ...              ...       ...      ...
# 32531     NonMarried                   ?    Not-in-family    Orient   Female
# 32532        Married      Prof-specialty          Husband  Occident     Male
# 32533        Married     Exec-managerial          Husband    Orient     Male
# 32534        Married        Adm-clerical        Unmarried  Occident   Female
# 32535     NonMarried     Protective-serv        Own-child    Orient     Male
# 32536     NonMarried     Exec-managerial    Not-in-family  Occident   Female
# 32537     NonMarried        Craft-repair    Not-in-family    Orient     Male
# 32538        Married      Prof-specialty        Unmarried    Orient   Female
# 32539        Married                   ?          Husband  Occident     Male
# 32540        Married        Adm-clerical        Own-child  Occident   Female
# 32541        Married                   ?    Not-in-family    Orient   Female
# 32542        Married                   ?          Husband  Occident     Male
# 32543        Married      Prof-specialty        Unmarried  Occident   Female
# 32544        Married       Other-service    Not-in-family    Orient   Female
# 32545        Married        Adm-clerical             Wife  Occident   Female
# 32546        Married        Tech-support    Not-in-family  Occident   Female
# 32547        Married   Machine-op-inspct          Husband  Occident     Male
# 32548     NonMarried      Prof-specialty    Not-in-family  Occident     Male
# 32549        Married        Adm-clerical   Other-relative  Occident   Female
# 32550        Married        Craft-repair          Husband  Occident     Male
# 32551        Married   Handlers-cleaners          Husband  Occident     Male
# 32552        Married               Sales          Husband  Occident     Male
# 32553     NonMarried        Tech-support    Not-in-family    Orient     Male
# 32554        Married     Exec-managerial          Husband  Occident     Male
# 32555     NonMarried     Protective-serv    Not-in-family  Occident     Male
# 32556        Married        Tech-support             Wife  Occident   Female
# 32557        Married   Machine-op-inspct          Husband  Occident     Male
# 32558        Married        Adm-clerical        Unmarried  Occident   Female
# 32559     NonMarried        Adm-clerical        Own-child  Occident     Male
# 32560        Married     Exec-managerial             Wife  Occident   Female
#
#       capital_gain capital_loss hours_per_week  native_country   incom
# 0             2174            0             40   United-States   <=50k
# 1                0            0             13   United-States   <=50k
# 2                0            0             40   United-States   <=50k
# 3                0            0             40   United-States   <=50k
# 4                0            0             40            Cuba   <=50k
# 5                0            0             40   United-States   <=50k
# 6                0            0             16         Jamaica   <=50k
# 7                0            0             45   United-States    >50k
# 8            14084            0             50   United-States    >50k
# 9             5178            0             40   United-States    >50k
# 10               0            0             80   United-States    >50k
# 11               0            0             40           India    >50k
# 12               0            0             30   United-States   <=50k
# 13               0            0             50   United-States   <=50k
# 14               0            0             40               ?    >50k
# 15               0            0             45          Mexico   <=50k
# 16               0            0             35   United-States   <=50k
# 17               0            0             40   United-States   <=50k
# 18               0            0             50   United-States   <=50k
# 19               0            0             45   United-States    >50k
# 20               0            0             60   United-States    >50k
# 21               0            0             20   United-States   <=50k
# 22               0            0             40   United-States   <=50k
# 23               0         2042             40   United-States   <=50k
# 24               0            0             40   United-States   <=50k
# 25               0            0             40   United-States    >50k
# 26               0            0             40   United-States   <=50k
# 27               0            0             60           South    >50k
# 28               0            0             80   United-States   <=50k
# 29               0            0             40   United-States   <=50k
# ...            ...          ...            ...             ...     ...
# 32531            0            0             99   United-States   <=50k
# 32532            0            0             60   United-States    >50k
# 32533            0            0             50           Japan    >50k
# 32534            0            0             39   United-States   <=50k
# 32535            0            0             35   United-States   <=50k
# 32536            0            0             55   United-States    >50k
# 32537            0            0             46   United-States   <=50k
# 32538        15020            0             45   United-States    >50k
# 32539            0            0             10   United-States    >50k
# 32540            0            0             40   United-States   <=50k
# 32541            0            0             32   United-States   <=50k
# 32542            0            0             25   United-States   <=50k
# 32543            0            0             48   United-States   <=50k
# 32544            0            0             30   United-States   <=50k
# 32545            0            0             20   United-States    >50k
# 32546            0            0             40   United-States   <=50k
# 32547            0            0             40          Mexico   <=50k
# 32548         1086            0             60   United-States   <=50k
# 32549            0            0             40   United-States   <=50k
# 32550            0            0             50   United-States   <=50k
# 32551            0            0             40   United-States   <=50k
# 32552            0            0             45   United-States   <=50k
# 32553            0            0             11          Taiwan   <=50k
# 32554            0            0             40   United-States    >50k
# 32555            0            0             40   United-States   <=50k
# 32556            0            0             38   United-States   <=50k
# 32557            0            0             40   United-States    >50k
# 32558            0            0             40   United-States   <=50k
# 32559            0            0             20   United-States   <=50k
# 32560        15024            0             40   United-States    >50k
#
# [32561 rows x 15 columns]

# %%
towrite_sort
# Out:
#           age          workclass  fnlwgt       education education_num  \
# 0        0-50          State-gov   77516      ProfSchool         13-16
# 1        0-50            Private   94235      ProfSchool         13-16
# 2        0-50            Private  195744      ProfSchool         13-16
# 3        0-50            Private   81896      ProfSchool         13-16
# 4        0-50            Private   45781      ProfSchool         13-16
# 5        0-50            Private  189265      ProfSchool         13-16
# 6        0-50            Private  238329      ProfSchool         13-16
# 7        0-50            Private  199915      ProfSchool         13-16
# 8        0-50            Private  122272      ProfSchool         13-16
# 9        0-50            Private  289748      ProfSchool         13-16
# 10       0-50            Private  196342      ProfSchool         13-16
# 11       0-50            Private  284531      ProfSchool         13-16
# 12       0-50          Local-gov  161942      ProfSchool         13-16
# 13       0-50       Self-emp-inc  142444      ProfSchool         13-16
# 14       0-50            Private  190539      ProfSchool         13-16
# 15       0-50            Private  511331      ProfSchool         13-16
# 16       0-50            Private  126754      ProfSchool         13-16
# 17       0-50            Private  202344      ProfSchool         13-16
# 18       0-50   Self-emp-not-inc  343721      ProfSchool         13-16
# 19       0-50          Local-gov  117833      ProfSchool         13-16
# 20       0-50            Private  159788      ProfSchool         13-16
# 21       0-50            Private  263831      ProfSchool         13-16
# 22       0-50            Private  168262      ProfSchool         13-16
# 23       0-50       Self-emp-inc  175958      ProfSchool         13-16
# 24       0-50          State-gov  210830      ProfSchool         13-16
# 25       0-50   Self-emp-not-inc  101266      ProfSchool         13-16
# 26       0-50            Private   96178      ProfSchool         13-16
# 27       0-50          State-gov  106334      ProfSchool         13-16
# 28       0-50            Private  122272      ProfSchool         13-16
# 29       0-50   Self-emp-not-inc  212041      ProfSchool         13-16
# ...       ...                ...     ...             ...           ...
# 32521  50-100        Federal-gov   86837      ProfSchool          6-12
# 32522  50-100            Private  108233      ProfSchool          6-12
# 32523  50-100            Private   47619      ProfSchool          6-12
# 32524  50-100                  ?  106707      ProfSchool          6-12
# 32525  50-100          Local-gov   92141      ProfSchool          6-12
# 32526  50-100          Local-gov  187749      ProfSchool          6-12
# 32527  50-100            Private  304260      ProfSchool          6-12
# 32528  50-100            Private  221791      ProfSchool          6-12
# 32529  50-100            Private  156040      ProfSchool          6-12
# 32530  50-100          State-gov  111130      ProfSchool          6-12
# 32531  50-100        Federal-gov   55621      ProfSchool          6-12
# 32532  50-100   Self-emp-not-inc  240236      ProfSchool          6-12
# 32533  50-100        Federal-gov  106257      ProfSchool          6-12
# 32534  50-100            Private  164198      ProfSchool          6-12
# 32535  50-100            Private  171780      ProfSchool          6-12
# 32536  50-100        Federal-gov  200700      ProfSchool          6-12
# 32537  50-100   Self-emp-not-inc  136836      ProfSchool          6-12
# 32538    0-50          State-gov  203279  AdvancedSchool         13-16
# 32539    0-50        Federal-gov   37683  AdvancedSchool         13-16
# 32540    0-50            Private  249870  AdvancedSchool         13-16
# 32541    0-50            Private  153078  AdvancedSchool         13-16
# 32542    0-50                  ?   98080  AdvancedSchool         13-16
# 32543    0-50        Federal-gov   49593  AdvancedSchool         13-16
# 32544    0-50            Private  158200  AdvancedSchool         13-16
# 32545    0-50            Private  110978  AdvancedSchool         13-16
# 32546    0-50            Private  236481  AdvancedSchool         13-16
# 32547    0-50            Private   98283  AdvancedSchool         13-16
# 32548    0-50            Private  176760  AdvancedSchool         13-16
# 32549    0-50            Private  172104  AdvancedSchool         13-16
# 32550    0-50            Private   98283  AdvancedSchool         13-16
#
#       marital_status          occupation    relationship      race      sex  \
# 0         NonMarried        Adm-clerical   Not-in-family  Occident     Male
# 1         NonMarried        Craft-repair       Unmarried  Occident     Male
# 2         NonMarried       Other-service   Not-in-family  Occident     Male
# 3         NonMarried      Prof-specialty   Not-in-family  Occident   Female
# 4         NonMarried      Prof-specialty   Not-in-family  Occident   Female
# 5         NonMarried     Exec-managerial   Not-in-family  Occident   Female
# 6         NonMarried               Sales   Not-in-family  Occident   Female
# 7         NonMarried        Adm-clerical       Own-child  Occident   Female
# 8         NonMarried        Adm-clerical       Own-child  Occident   Female
# 9         NonMarried     Exec-managerial   Not-in-family  Occident   Female
# 10        NonMarried      Prof-specialty   Not-in-family  Occident     Male
# 11        NonMarried               Sales   Not-in-family  Occident   Female
# 12        NonMarried        Adm-clerical   Not-in-family  Occident   Female
# 13        NonMarried      Prof-specialty   Not-in-family  Occident   Female
# 14        NonMarried               Sales   Not-in-family  Occident     Male
# 15        NonMarried               Sales   Not-in-family  Occident     Male
# 16        NonMarried     Exec-managerial   Not-in-family  Occident     Male
# 17        NonMarried      Prof-specialty       Own-child  Occident   Female
# 18        NonMarried      Prof-specialty   Not-in-family  Occident     Male
# 19        NonMarried      Prof-specialty   Not-in-family  Occident   Female
# 20        NonMarried      Prof-specialty   Not-in-family  Occident   Female
# 21        NonMarried        Adm-clerical       Own-child  Occident   Female
# 22        NonMarried        Adm-clerical       Own-child  Occident     Male
# 23        NonMarried               Sales   Not-in-family  Occident     Male
# 24        NonMarried      Prof-specialty       Own-child  Occident   Female
# 25        NonMarried               Sales   Not-in-family  Occident     Male
# 26        NonMarried        Adm-clerical       Own-child  Occident   Female
# 27        NonMarried     Exec-managerial   Not-in-family  Occident     Male
# 28        NonMarried     Farming-fishing       Own-child  Occident   Female
# 29        NonMarried               Sales   Not-in-family  Occident     Male
# ...              ...                 ...             ...       ...      ...
# 32521        Married       Other-service         Husband    Orient     Male
# 32522        Married       Other-service   Not-in-family    Orient   Female
# 32523        Married      Prof-specialty   Not-in-family    Orient   Female
# 32524        Married                   ?         Husband    Orient     Male
# 32525        Married        Adm-clerical   Not-in-family    Orient   Female
# 32526        Married        Adm-clerical         Husband    Orient     Male
# 32527        Married        Adm-clerical   Not-in-family    Orient     Male
# 32528        Married        Tech-support         Husband    Orient     Male
# 32529        Married   Machine-op-inspct         Husband    Orient     Male
# 32530        Married        Adm-clerical       Own-child    Orient     Male
# 32531        Married       Other-service         Husband    Orient     Male
# 32532        Married               Sales   Not-in-family    Orient     Male
# 32533        Married        Tech-support         Husband    Orient     Male
# 32534        Married   Handlers-cleaners         Husband    Orient     Male
# 32535        Married               Sales       Unmarried    Orient   Female
# 32536        Married     Farming-fishing         Husband    Orient     Male
# 32537        Married    Transport-moving       Unmarried    Orient   Female
# 32538     NonMarried      Prof-specialty   Not-in-family    Orient     Male
# 32539     NonMarried      Prof-specialty   Not-in-family    Orient   Female
# 32540     NonMarried      Prof-specialty   Not-in-family    Orient     Male
# 32541     NonMarried      Prof-specialty       Own-child    Orient     Male
# 32542     NonMarried                   ?   Not-in-family    Orient     Male
# 32543     NonMarried      Prof-specialty   Not-in-family    Orient   Female
# 32544     NonMarried      Prof-specialty       Own-child    Orient   Female
# 32545     NonMarried      Prof-specialty   Not-in-family    Orient   Female
# 32546     NonMarried      Prof-specialty   Not-in-family    Orient     Male
# 32547     NonMarried        Tech-support   Not-in-family    Orient     Male
# 32548     NonMarried      Prof-specialty   Not-in-family    Orient     Male
# 32549     NonMarried      Prof-specialty   Not-in-family    Orient     Male
# 32550     NonMarried      Prof-specialty   Not-in-family    Orient     Male
#
#       capital_gain capital_loss hours_per_week  native_country   incom
# 0             2174            0             40   United-States   <=50k
# 1                0            0             40   United-States   <=50k
# 2                0            0             48   United-States   <=50k
# 3                0            0             45   United-States   <=50k
# 4            14084            0             50   United-States    >50k
# 5                0            0             40   United-States   <=50k
# 6                0            0             45   United-States   <=50k
# 7                0            0             35   United-States   <=50k
# 8                0            0             30   United-States   <=50k
# 9             4650            0             48   United-States   <=50k
# 10               0            0             40   United-States    >50k
# 11               0            0             40   United-States   <=50k
# 12            1055            0             40   United-States   <=50k
# 13               0            0             45   United-States   <=50k
# 14            6849            0             48   United-States   <=50k
# 15               0            0             38   United-States   <=50k
# 16               0            0             45   United-States    >50k
# 17               0            0             40   United-States   <=50k
# 18               0            0             30               ?    >50k
# 19            4865            0             35   United-States   <=50k
# 20               0            0             80   United-States   <=50k
# 21               0            0             40   United-States   <=50k
# 22               0            0             40   United-States   <=50k
# 23            3325            0             60   United-States   <=50k
# 24               0            0             30   United-States   <=50k
# 25               0            0             62   United-States   <=50k
# 26               0            0             40   United-States   <=50k
# 27               0            0             40               ?   <=50k
# 28               0            0             40   United-States   <=50k
# 29               0            0             50   United-States   <=50k
# ...            ...          ...            ...             ...     ...
# 32521            0            0             40   United-States    >50k
# 32522            0            0             40   United-States   <=50k
# 32523            0            0             40   United-States   <=50k
# 32524            0            0             20   United-States    >50k
# 32525            0            0             40   United-States   <=50k
# 32526            0            0             20     Philippines   <=50k
# 32527            0            0             40   United-States   <=50k
# 32528            0            0             40   United-States   <=50k
# 32529            0         1848             40   United-States    >50k
# 32530            0            0             40   United-States   <=50k
# 32531            0            0             40   United-States   <=50k
# 32532            0            0             30   United-States   <=50k
# 32533            0            0             40   United-States   <=50k
# 32534        15024            0             45   United-States    >50k
# 32535            0            0             30   United-States   <=50k
# 32536            0            0             40   United-States   <=50k
# 32537            0            0             30   United-States   <=50k
# 32538         2463            0             50           India   <=50k
# 32539        99999            0             57          Canada    >50k
# 32540            0            0             50   United-States   <=50k
# 32541            0            0             40   United-States   <=50k
# 32542         4787            0             45           Japan    >50k
# 32543            0            0             40   United-States   <=50k
# 32544            0            0             40               ?   <=50k
# 32545            0            0             40   United-States   <=50k
# 32546            0            0             10           India   <=50k
# 32547            0         1564             40           India    >50k
# 32548            0            0             55   United-States   <=50k
# 32549            0            0             40           India    >50k
# 32550            0            0             40           India    >50k
#
# [32551 rows x 15 columns]

# %%
def cac_avg_age(df, type = 1,dellist = []):
    #df = readdata()
    newage=[]
    if type==1:
        for idx, record in df.iterrows():
            if record['age']=="0-25":
                newage.append(12.5)
            elif record['age']=="25-50":
                newage.append(37.5)
            elif record['age']=="50-75":
                newage.append(62.5)
            elif record['age']=="75-100":
                newage.append(87.5)
            elif record['age']=="0-50":
                newage.append(25)
            else :
                newage.append(75)
    else: 
        newage = df['age']
    
    if len(dellist)!=0:
        for i in dellist:
            del newage[i]
    return sum(newage)/len(newage)

# %%
#初始化参数
k = 10
real_avg_age = 0
dellist = []
mistake = {'real':[],'k_anonymize':[],'DP':[]}
xlist = []
ylist = []

records = readdata()
avg_age = cac_avg_age(records, type=2, dellist=dellist)
real_avg_age = avg_age
print("真实平均年龄：\n",real_avg_age)

k = int(input("请输入k值\n"))
KAnony = KAnonymity(records)
newdf=KAnony.anonymize(qi_names=['age', 'education'], k = k)
#newdf=KAnony.anonymize(k = k)
avg_age_k = cac_avg_age(newdf, type=1, dellist=dellist)

#差分攻击
mistake['k_anonymize'].append(avg_age_k)
print("K-匿名后平均年龄：",avg_age_k)

while(1):
    delp = int(input("请输入要删除的索引:(按-1结束)\n"))  
    if delp == -1:
        break
    dellist.append(delp)
    if len(dellist)!=0:
        for i in dellist:
            print("删除索引为{},年龄为{}".format(i,records['age'][i]))
            records = records.drop(i)

avg_age_k = cac_avg_age(newdf, type=1, dellist=dellist)
#差分攻击
mistake['k_anonymize'].append(avg_age_k)
print("执行以上操作后K-匿名后平均年龄：\n",avg_age_k)
age_predict = mistake['k_anonymize'][0]*(len(records)+len(dellist)) - avg_age_k*len(records)
print("根据前后数值差分攻击得到删除掉的年龄为：\n",age_predict)
del mistake['k_anonymize'][1]
if len(dellist)>0:
    del dellist[0]
# Out:
# 真实平均年龄：
#  38.58164675532078
# 请输入k值
# 5
# qi names:  ['age', 'education']
# attribute gen level: [1, 1]
# tree height: [3, 4]
# precision: 0.7083333333333334, distoration: 0.29166666666666663
# K-匿名后平均年龄： 38.865130063572984
# 请输入要删除的索引:(按-1结束)
# 0
# 删除索引为0,年龄为39
# 请输入要删除的索引:(按-1结束)
# -1
# 执行以上操作后K-匿名后平均年龄：
#  38.86517199017199
# 根据前后数值差分攻击得到删除掉的年龄为：
#  37.5
